# %% [markdown]
# <a href="https://colab.research.google.com/github/kakshayasailu/heart-chronic-disease-prediction/blob/main/heart_disease_prediction_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras

# %%
from keras.models import Sequential
model=Sequential()

# %%
from keras.layers import Dense

# %%
import pandas as pd
dt=pd.read_csv('/content/heart (1).csv')
dt.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
dt.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.103240 -0.071966  0.271121  0.219823  0.121243
# sex      -0.103240  1.000000 -0.041119 -0.078974 -0.198258  0.027200
# cp       -0.071966 -0.041119  1.000000  0.038177 -0.081641  0.079294
# trestbps  0.271121 -0.078974  0.038177  1.000000  0.127977  0.181767
# chol      0.219823 -0.198258 -0.081641  0.127977  1.000000  0.026917
# fbs       0.121243  0.027200  0.079294  0.181767  0.026917  1.000000
# restecg  -0.132696 -0.055117  0.043581 -0.123794 -0.147410 -0.104051
# thalach  -0.390227 -0.049365  0.306839 -0.039264 -0.021772 -0.008866
# exang     0.088163  0.139157 -0.401513  0.061197  0.067382  0.049261
# oldpeak   0.208137  0.084687 -0.174733  0.187434  0.064880  0.010859
# slope    -0.169105 -0.026666  0.131633 -0.120445 -0.014248 -0.061902
# ca        0.271551  0.111729 -0.176206  0.104554  0.074259  0.137156
# thal      0.072297  0.198424 -0.163341  0.059276  0.100244 -0.042177
# ...

# %%
dt=dt.drop(['chol','fbs'],axis=1)

# %%
dt.head()
# Out:
#    age  sex  cp  trestbps  restecg  thalach  exang  oldpeak  slope  ca  thal  \
# 0   52    1   0       125        1      168      0      1.0      2   2     3
# 1   53    1   0       140        0      155      1      3.1      0   0     3
# 2   70    1   0       145        1      125      1      2.6      0   0     3
# 3   61    1   0       148        1      161      0      0.0      2   1     3
# 4   62    0   0       138        1      106      0      1.9      1   3     2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
x=dt.iloc[:,0:11]
y=dt['target']

# %%
x
# Out:
#       age  sex  cp  trestbps  restecg  thalach  exang  oldpeak  slope  ca  \
# 0      52    1   0       125        1      168      0      1.0      2   2
# 1      53    1   0       140        0      155      1      3.1      0   0
# 2      70    1   0       145        1      125      1      2.6      0   0
# 3      61    1   0       148        1      161      0      0.0      2   1
# 4      62    0   0       138        1      106      0      1.9      1   3
# ...   ...  ...  ..       ...      ...      ...    ...      ...    ...  ..
# 1020   59    1   1       140        1      164      1      0.0      2   0
# 1021   60    1   0       125        0      141      1      2.8      1   1
# 1022   47    1   0       110        0      118      1      1.0      1   1
# 1023   50    0   0       110        0      159      0      0.0      2   0
# 1024   54    1   0       120        1      113      0      1.4      1   1
#
#       thal
# 0        3
# 1        3
# 2        3
# 3        3
# 4        2
# ...

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1020    1
# 1021    0
# 1022    0
# 1023    1
# 1024    0
# Name: target, Length: 1025, dtype: int64

# %%
print(y)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1020    1
# 1021    0
# 1022    0
# 1023    1
# 1024    0
# Name: target, Length: 1025, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
print(x.shape,y.shape,x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (1025, 11) (1025,) (768, 11) (257, 11) (768,) (257,)

# %%
model.add(Dense(units=11,activation='relu'))
model.add(Dense(units=5,activation='relu'))
model.add(Dense(units=1,activation='sigmoid'))

# %%
model.build(input_shape=(None,11))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 11)             │           132 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │            60 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             6 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 11)             │            22 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 5)              │            60 │
# ...

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=100,batch_size=8,steps_per_epoch=x_train.shape[0]//8)
# Out:
# Epoch 1/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5799 - loss: 0.6458
# Epoch 2/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7904 - loss: 0.5776
# Epoch 3/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8204 - loss: 0.5296
# Epoch 4/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8122 - loss: 0.5011
# Epoch 5/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8105 - loss: 0.4911
# Epoch 6/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8220 - loss: 0.4631
# Epoch 7/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8384 - loss: 0.4253
# Epoch 8/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.4215
# Epoch 9/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8501 - loss: 0.3912
# Epoch 10/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8071 - loss: 0.4408
# Epoch 11/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8304 - loss: 0.4055
# Epoch 12/100
# ...

# %%
model.save('heart.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
